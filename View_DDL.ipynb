# %%
import pyodbc
import re
import pandas as pd
conn = pyodbc.connect("Driver={SQL Server};"
                              "Server=ussltcsnw1940.solutions.glbsnet.com;"
                              "Database=DATAFIRST;"
                              "UID=deesaw;"
                              "PWD=Welcome@123")
list=[
'tvMAST_BOM_Components_Marked_Deletion_Report'
,'tvMAST_BOM_Components_Marked_Deletion_Report'
,'tvMARA_MaterialGroup_Rpt'
,'tvMARA_ZSOURCE_LegData_SrcSys_Ref_Rpt'
,'tvMARA_Relevancy_Open_Sales_Order'
,'[tvMARA_Relevancy_SalesOrder_Within_ZOldDays]'
,'[tvMARA_Relevancy_Material_Having_Inventory]'
#,'tvMAST_MaterialBOMHEADER_Rpt'
,'tvMAKT_MaterialDescrition_Rpt'
,'tvVBAP_MATNR_ERSDA_Created_zNewDays_Rpt'
,'[tvMARA_Relevancy_Material_With_Open_PO]'
,'[tvMARA_Relevancy_PurchaseOrder_Within_ZOldDays]'
,'[tvMARA_Relevancy_Material_Having_Inventory_Within_ZOldDays]'
,'tvMAST_MaterialBOMComponent_Rpt'
,'tvMAPL_PLKO_PLAS_PLFL_PLPO_N_Routing_ConvFactor_Material_Compare_Rpt'
,'[tvMARA_Buy_WithPurchaseView_BMATN_Missing_HERS_Managed_Rpt]'
,'tvMARA_BSTME_ProcExt_Buy_WithPurchView_MissingOrderUnit_Rpt'
,'tvMARA_Buy_WithPurchView_BSTME_MissingOrderUnit_Rpt'
,'[tvMARA_Relevancy_All_ERSDA_DailyCreate_ByUser_Rpt]'
,'tvMAPL_MAPL_Routing_Without_MAST_Rpt'
,'tvMARA_Relevancy_All_ERSDA_DailyCreate_ByUser_Rpt'
,'tvMARA_Manufactured_Material_NeverBeenOnPO_Rpt'
,'tvMARA_NonStockMaterial_NotStocked_With_StorageLoc_Rpt'
,'[tvMARA_VRKME_SalesUoM_Blank_LVSMW_WHUoM_And_AUSMW_UnitOfIssue_NotBlank_Rpt]'
,'tvMARA_SellMaterial_Missing_SalesGeneralPlant_View_Rpt'
,'tvMARA_SellMaterial_MVKE_SalesOrgView_Missing_Rpt'
,'tvMARA_MATKL_MaterialGroup_Missing_Rpt'
,'tvMARA_PSTAT_HasNoMRPViewPlant_Rpt'
,'[tvMARA_Stock_Material_PSTAT_L_HasStorageView_MissingStorageLoc_Rpt]'
,'tvMARA_Stock_Material_PotentiallyObsolete_Rpt'
,'[tvMARC_Buy_Material_EINA_Missing_InfoRecord_Rpt]'
,'tvEINA_UOM_ConvFactor_InfoRec_To_Material_Different_Rpt'
,'tvMARA_Buy_EKPO_NeverBeenPurchased_Rpt'
,'tvMARA_Sell_Material_VBAP_Material_WithNoSales_Rpt'
,'tvMARA_Stock_Material_BRGEW_MissingGrossWeight_Rpt'
,'tvMARA_Stock_Material_PSTAT_L_HasStorageView_MissingStorageLoc_Rpt'
,'tvMARC_Buy_Material_KAUTB_AutoPO_Missing_Rpt'
,'[tvMARC_Buy_Material_EKKO_BSTYP_K_Contract_Missing_Rpt]'
,'tvMAKT_MAKTX_Description_Contains_SpecialCharacter_Rpt'
,'tvMARA_MakeMaterials_MARC_HasMRPView_OnlyProcuredExternally_Rpt'
,'tvMARA_Stock_Material_MHDRZ_MinShelfLifeRemain_LT1_Rpt'
,'tvMARA_Material_That_Are_Not_Stocked_In_ZOldDays_Rpt'
,'tvMARC_Buy_Material_KAUTB_AutoPO_Missing_Rpt'
,'tvMARC_Buy_Material_EKKO_BSTYP_K_Contract_Missing_Rpt'
,'tvEINE_NETPR_InfoRecord_MissingPrice_Rpt'
,'tvMAPL_BOMWithNoRouting'
,'tvMARA_MARC_NotExtendedToAnyPlant_Rpt'
,'tvMARA_MATKL_MaterialGroup_Missing_Rpt'
,'[tvMARA_CostedMaterial_Missing_CostingView_Rpt]'
,'[tv_MARC_BESKZ_EKGRP_EXTERNALLY_PROCURED__Rpt]'
,'tvMARC_EKGRP_Missing_ExternallyProcured_Rpt'
,'tvMARA_Relevancy_All_ERSDA_DailyCreate_Rpt'
,'[tv_MAST_MATNR_STLNR_IDNRK_BOM_MATERIAL_WITH_DIFF_COMPONENT_Rpt]'
,'[tvMARA_MATKL_MaterialGroup_Missing_Length_GreaterThan9_Rpt]'
,'tvMARA_Relevancy_All_ERSDA_WERKS_DailyCreate_Rpt'
,'tvMARA_Relevancy_All_ERSDA_WERKS_MonthlyCreate_Rpt'
,'tvMARA_Relevancy_All_ERSDA_VKORG_DailyCreate_Rpt'
,'tvMARA_Relevancy_All_ERSDA_VKORG_MonthlyCreate_Rpt'
,'tvMARA_Relevancy_All_ERSDA_LGORT_DailyCreate_Rpt'
,'tvMARA_Relevancy_All_ERSDA_LGORT_MonthlyCreate_Rpt'
,'tvMARA_Relevancy_All_ERSDA_BWKEY_DailyCreate_Rpt'
,'tvMARA_Relevancy_All_ERSDA_BWKEY_MonthlyCreate_Rpt'
,'tvMARA_Relevancy_All_ERSDA_LGNUM_DailyCreate_Rpt'
,'[tvMARA_Relevancy_All_ERSDA_LGNUM_MonthlyCreate_Rpt]'
,'tvMARA_MHDRZ_MissingShelfLife_Rpt'
,'tvMARC_BESKZ_InHouseProcurement_AUSSS_AssblyScrapMissing__Rpt'
,'tvMARC_BESKZ_SOBSL_MTART_WERKS_GroupBy_Count_Rpt'
,'tvMARA_EKPO_EKKO_EBELN_Rpt'
,'tvMARA_MaterialBaseUnitOfMeasure_Rpt'
,'tvMARA_MaterialPurchasingValueKey_Rpt'
,'tvMARA_GEWEI_HasNullGEWEI_Rpt'
,'tvMARA_TRAGR_HasNullTRAGR_Rpt'
,'tvMARA_Material_That_Are_Not_Manufactured_In_ZOldDays_Rpt'
,'tvMARA_Stock_Material_PSTAT_L_HasStorageView_XCHPF_NotBatchManaged_Rpt'
,'tvMARA_Stock_Material_PSTAT_L_HasStorageView_LGNUM_Blank_NoWarehouse_Rpt'
,'tvMARA_Stock_Materials_MaterialsNeverBeenStocked_Rpt'
,'tvMAKT_MAKTX_Description_InformalUseOf_Rpt'
,'[tvMAPL_PLKO_PLPO_N_Routing_AUFAK_ScrapMissing_Rpt]'
,'[tvMARA_Relevancy_All_EAN11_Duplicate_Detail_Rpt]'
,'tvMARA_Buy_BSTME_OrderUnitBlank_VABME_VariableOrderUnit_Populated_Rpt'
,'[tv_MARA_HERS_MAKTX_NOT_SAME_Rpt]'
,'tvMARA_MBEW_MVKE_FinishedMaterialWithSalesAccountingData_Rpt'
,'tvMARA_MAKTX_InternalDesc_MAKTX_HERSDescription_Different_Rpt'
,'tvMARA_Relevancy_All_ManufacturerParts_MFRNR_Missing_Rpt'
,'[tv_RefIntegrity_MARC_BESKZ_PSTAT_NOTMANUFACTURED_WITHMRP_Rpt]'
,'[tvMARA_NonStockMaterial_NotStocked_With_StorageLoc_Rpt]'
,'tvMARA_VRKME_SalesUoM_Blank_LVSMW_WHUoM_And_AUSMW_UnitOfIssue_NotBlank_Rpt'
,'tvMARA_STOFF_HazMaterialNum_Duplicates_Rpt'
,'tvMARA_BroughtMaterials_MAST_WithBOM_Rpt'
,'tvMARC_BESKZ_F_BroughtMaterials_MAST_WithBOM_Rpt'
#,'tvMVKE_Count_of_Materials_Extended_To Sales_Org_Rpt'
,'[tvMARA_Relevancy_1ProductHierarchy_Multiple_Finished_Goods]'
,'[tv_MARC_PSTAT_MBEW_BWKEY_VPRSV_PEINH_RAW_PROCURED_MATERIALS_PURCHASE_ACCOUNTING_VIEW_Rpt]'
,'tvLQUA_VERME_DecimalQuant_Rpt'
,'tvMARA_CostedMaterialMissingCostingData_Rpt'
,'[tv_MARA_EAN11_EANISNOTMATIANED_OR_EAN11ISGREATERTHAN18_Rpt]'
,'tvMARA_Relevancy_All_Active_Material_Rpt'
,'tvMBEW_VPRSV_ValuatedMaterialWithPriceControl_Rpt'
,'[tv_MARA_MVKE_MBEW_SEMI_FINISHED_SALES_ACCOUNTING_Rpt]'
,'tvMARM_AltUOM_UMREZ_MissingNumerator_Rpt'
,'tvMARA_MARC_PlantExtensionMissing_Rpt'
,'tvMARA_STOFF_HazardMaterial_Rpt'
,'tvMARC_Material_EINA_Missing_InfoRecord_Rpt'
,'[tv_PE_MARC_QMATV_QINF_MISSINGQUALITYINFORECORD_Rpt]'
,'[tv_MN_MARC_PLIFZ_MISSINGPLANNEDDELIVERYTIME_Rpt]'
,'tvMARA_BRGEW_MissingGrossWeight_FinishedMaterial_Rpt'
,'tvMARC_SOBSL_Missing_ExternallyProcured_Rpt'
,'[tvMARC_ProcurementType_E_SOBSL_NotNull]'
,'[tv_MARA_RDMHD_LENGTH_LESS_THAN_EQUAL_TO1_Rpt]'
,'tvMARA_Length_Of_MANUFACTURER_PART_NUMBER_Rpt'
,'tvMARA_Length_Of_TOTAL_SHELF_LIFE_Rpt'
,'tvMARA_Length_Of_MATERIAL_DESCRIPTION_Rpt'
,'tvMARA_Length_Of_MATERIAL_NUMBER_Rpt'
,'tvMARA_MTPOS_MARA_BasicViewWithBlankItemCtgryGrp_Rpt'
,'tvMARA_PRDHA_BasicViewWithBlankProductHierarchy_Rpt'
,'tvMARA_Buy_Material_No_PO_LastzOldDays_Obsolete_Rpt'
,'tvMARA_MissingExpirationDate_Rpt'
,'tvMARA_NoMakeMaterial_PSTAT_D_WithMRPViews_Rpt'
,'[tv_MARC_PSTAT_MATERIALS_NOT_SOLD_HAVING_SALES_VIEW_Rpt]'
,'tvMARC_MakeOrBuyMaterials_WEBAZ_GRProcTimeMissing_Rpt'
,'[tvMARA_NoBuyMaterials_WithPurchasingView_Rpt]'
,'tvMARA_NoStock_NotStocked_WithStorageView_Rpt'
,'[tvMARA_Sell_Material_ZOldDays_MM_141]'
,'tvMARA_Sell_Material_PotentiallyObsolete_Rpt'
,'[tv_MARC_BESKZ_AUSSS_INHOUSE_NO_ASSEMBLYSCRAP_Rpt]'
,'[tv_MARA_DUPLICATESBASEDON_MTART_MAKTX_MATKL_MEINS_Rpt]'
,'tvMARA_KZUMW_EnvironRelevant_SUBID_MissingSpec_Rpt'
,'tvMARA_All_ManufacturerParts_MSTAE_MissingXPlantStatus_Rpt'
,'tvMARA_Relevancy_All_ManufacturerParts_MATKL_Missing_Rpt'
,'tvMARA_Relevancy_All_ManufacturerParts_MATKL_Missing_Rpt'
,'tvMAKT_SPRAS_ExportMaterialNoDescription_Rpt'
,'[tv_MARA_GROES_SIZE_DIMENSION_NOT_MAINTAINED_Rpt]'
,'[tv_MARA_BRGEW_NTGEW_GEWEI_GROSSNETWEIGHT_WEIGHTUNIT_NOT_MAINTAINED_Rpt]'
,'tvMARA_ZACTIVE_MaterialNotActive_Rpt'
,'tvMARA_MVKE_MTPOS_SalesViewWithBlankItemCtgryGrp_Rpt'
,'tvMARA_MVKE_PRODH_SalesViewWithBlankProductHierarchy_Rpt']
for v in list:
    print(v)
    script="exec sp_helptext 'dbo."+v+"';"
    cursor = conn.cursor()
    script="exec sp_helptext 'dbo."+v+"';"
    sql_query = pd.read_sql_query(script,conn)
    a=v+'.xlsx'
    sql_query.to_excel(a,index=False)
# Out:
# tvMAST_BOM_Components_Marked_Deletion_Report
# tvMAST_BOM_Components_Marked_Deletion_Report
# tvMARA_MaterialGroup_Rpt
# tvMARA_ZSOURCE_LegData_SrcSys_Ref_Rpt
# tvMARA_Relevancy_Open_Sales_Order
# [tvMARA_Relevancy_SalesOrder_Within_ZOldDays]
# [tvMARA_Relevancy_Material_Having_Inventory]
# tvMAKT_MaterialDescrition_Rpt
# tvVBAP_MATNR_ERSDA_Created_zNewDays_Rpt
# [tvMARA_Relevancy_Material_With_Open_PO]
# [tvMARA_Relevancy_PurchaseOrder_Within_ZOldDays]
# [tvMARA_Relevancy_Material_Having_Inventory_Within_ZOldDays]
# tvMAST_MaterialBOMComponent_Rpt
# tvMAPL_PLKO_PLAS_PLFL_PLPO_N_Routing_ConvFactor_Material_Compare_Rpt
# [tvMARA_Buy_WithPurchaseView_BMATN_Missing_HERS_Managed_Rpt]
# tvMARA_BSTME_ProcExt_Buy_WithPurchView_MissingOrderUnit_Rpt
# tvMARA_Buy_WithPurchView_BSTME_MissingOrderUnit_Rpt
# [tvMARA_Relevancy_All_ERSDA_DailyCreate_ByUser_Rpt]
# tvMAPL_MAPL_Routing_Without_MAST_Rpt
# tvMARA_Relevancy_All_ERSDA_DailyCreate_ByUser_Rpt
# ...
